# %%
import requests 
import json

# %%
with open("test.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
import requests

url = "http://localhost:8005/convertTexting"
headers = {
    "accept": "application/json",
    "Content-Type": "application/json"
}


response = requests.post(url, json=data)

print(response.status_code)
print(response.json())
# Out:
# 200
# ...
